# %%
import numpy as np
import math
import pandas
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense, SimpleRNN, LSTM, Flatten
from sklearn.cluster import DBSCAN, KMeans
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
x_train = [[5],[10],[6],[12],[11],[9]]
y_train = [[20,33], [1,28], [2, 51], [16,27], [9,32], [4, 49]]

# %% [markdown]
# 5: 20,33
# 10: 1, 28
# 6: 2, 51
# 12: 16, 27
# 11: 9, 32
# 9: 4, 49
#
# что?
# еще раз
#
# а пон, ок,

# %%
model = keras.Sequential()
model = keras.Sequential()
model.add(Dense(input_dim = 1, units=50, activation='relu')) 
model.add(Dense(units=50, activation='relu')) 
model.add(Dense(activation = 'relu', units = 50))
model.add(Dense(units = 2))
model.compile(optimizer = 'RMSProp', loss = 'hinge')

model.fit(x_train, y_train, epochs = 200)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 1s 978ms/step - loss: 1.9092
# Epoch 2/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0430
# Epoch 3/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0318
# Epoch 4/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0199
# Epoch 5/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0120
# Epoch 6/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0097
# Epoch 7/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0071
# Epoch 8/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0042
# Epoch 9/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 10/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00
# Epoch 11/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0000e+00
# Epoch 12/200
# ...

# %%
model.predict([[5]])
# Out:
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019F1AFBA828> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[0.53014207, 0.6733016 ]], dtype=float32)

# %%
import numpy as np

from keras.models import Sequential
from keras.layers import LSTM, Dense


X_train = [[10],[6],[5],[12],[11],[9]]
y_train = [[1],[2],[20],[16],[10],[4]]

ad = keras.optimizers.Adam(1)

model = Sequential()
model.add(Dense(activation = 'relu', input_dim = 1, units=50))
model.add(Dense(units=20, activation = 'relu'))
model.add(Dense(units=1))
model.compile(optimizer = ad, loss = 'mse')

model.fit(X_train, y_train, epochs = 10, verbose = 0)

X_test = 10
y_predicted = model.predict([[X_test]])

print(y_predicted)

plt.plot(X_train, y_train)
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000249628C6558> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[1.4381707]]

# %% [markdown]
# хуета однозначно
# говно
# ты ебанутый, это не решается регрессией?!
